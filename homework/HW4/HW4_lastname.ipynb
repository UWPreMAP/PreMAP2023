# %% [markdown]
# **<font color='red'>Change the name from assignment_lastname to include YOUR last name</font>**. This will make sure that the assignment doesn't get overwritten when you do a ```git pull``` in class.

# %% [markdown]
# # Homework 4B - the coding portion

# %% [markdown]
# ## Due: Monday, October 16, by 11:59pm

# %% [markdown]
# Skills: numpy, basic python

# %% [markdown]
# Turn in instructions:
# 1. Before turning in your notebook, make sure you save it first using the floppy disk save icon or File -> save.
# 2. You don't need to e-mail the file to me, as long as the HW4_lastname (replace lastname with your last name) file exists on the JupyterHub, I'll be able to see it.

# %% [markdown]
# Always start with your import statement! You will only need the package `numpy` for today's homework

# %%
#We're going to be using numpy in this homework, so we need to import it first.
import numpy as np

#The next command makes sure that when I try to display images they show to the notebook screen
# %matplotlib inline

# %% [markdown]
# ### The exercises in this coding assignment will be based on the article you read for Homework 4B. You can find a link to the article [here](https://astrobites.org/2018/07/18/best-exoplanet-destinations-for-mountain-climbers/).

# %% [markdown]
# **Before you get started:**
# Remember that you have many tools to help you out with coding! First, please reference the notebooks we've been working through in class. Great coders copy their old code ALL THE TIME, it is a great resource! You should also make Google your best friend for code questions. Don't hesitate to google your questions. Lastly, you should get familiar with the built in documentation for python and python packages such as numpy. You can access help pages by typing the function name, followed by a ? in a coding cell and then executing it.

# %% [markdown]
# **1)**
# Use the `print` command to print the title of the astrobites article to the screen.

# %%
print('')

# %% [markdown]
# Using Figure 1 from the paper as a reference, we're going to use Python to do some calculations for us:
# ![image.png](attachment:image.png)
#
# <b>Do not run the below cell! It's there to just display the figure from the paper</b>

# %%
#IGNORE THIS CELL - I'm just using it to display Figure 1 from the paper.
from IPython.display import Image
from IPython.display import display
lc = Image(filename='/astro/users/mlazz/PreMAP2019/homework/data/exomountain_trainsit.png') 
display(lc)

# %% [markdown]
# <b>2)</b> Why is the highest value of the relative flux above equal to 1? What does it mean if the relative flux received is less than 1? Answer this question by editing the markdown cell below.

# %% [markdown]
# Your answer to question 2 goes in this cell

# %% [markdown]
# **3)**
# Create a variable called `delta_sphere` and a variable called `delta_block`. Assuming that the bottom of the graph is 0, choose a reasonable value for both variables between 0 and 1.

# %%
delta_sphere = 
delta_block =

# %% [markdown]
# **4)** How much larger is `delta_sphere` than `delta_block`?

# %% [markdown]
# Your answer goes in this cell

# %% [markdown]
# **5)**
# From the paper, we know that the transit depth, $\delta$ is related to the cross-sectional area of the planet, A, and the radius of the host star, R, using the equation: $\delta_\mathrm{sphere} = \frac{A}{\pi R^{2}}$.
#
# Using your value for `delta_sphere` above, if the cross-sectional area ($A$) of the planet is 0.5, what is the radius of the host star? Print the radius to the screen. *Hint: the value of $\pi$ is built into `numpy`, you can use it by typing `np.pi`.*

# %%
A = 0.5
R = 
print(R)

# %% [markdown]
# **6)**
# Let's say you had a whole bunch of these observations and wanted to calculate the radii of a bunch of stars. Create a numpy array called `areas` that contains 10 cross-sectional areas evenly spaced out between 0.1 and 1 (including both 0.1 and 1). Print your `areas` array to the screen. Calculate the radius of the host star for each planet with an area in the `areas` array.
#
# Using just this areas array and ```np.pi```, create an array called `radii` that contains the radius of each of thse host stars and print it to the screen.

# %%
areas =

# %%
print(areas)

# %%
radii = 
print(radii)

# %% [markdown]
# **7)** Let's do some math with these numbers, just to test out some of the handy calculations we can do with python and the numpy package. Raise every value of the `radii` array to the 2nd power. Trick - do this two different ways! You will soon learn that there are always multiple ways to do something with Python, and usually more than one good way to do it! You can raise an array to a power using just normal python math operators (+, -, $*$, $**$, etc.) and with the built in `numpy` function `np.power`. Please show that you can do it both ways in the empty cell below.

# %% [markdown]
# Helpful hint, if you aren't sure what arguments the `np.power` function takes, read its help docs by executing the cell below.

# %%
np.power? # run this cell

# %% [markdown]
# **8)** Sum up the radius of each host star in the `radii` array.

# %% [markdown]
# **9)** Subtract 0.5 from each value in the `radii` array.

# %% [markdown]
# **10)** Divide each value of the radii array by 2.

# %% [markdown]
# **11)** Let's create a new array of star radii called `new_radii`. The `new_radii` array should contain all multiples of 3 between 0 and 999, including 999. Print `new_radii` to the screen.

# %% [markdown]
# **12)** Calculate the cross sectional area, of the planet for each of the host stars in the `new_radii` array. Save these values in an array called `new_areas`.

# %% [markdown]
# **13)** You might notice that when you print out `new_areas` that the values are listed in scientific notation. This is a useful feature of Python, especially when working with big numbers like we do in astronomy. Print the 5th element of the `new_areas` array to the screen. *Hint: remember that Python indexes starting with 0.

# %% [markdown]
# **14)** What is the sum of the cross sectional areas of all of the planets in the `new_areas` array?

# %% [markdown]
# **15)** What is the sum of the radii of all of the stars in the `new_radii` array with a radius of greater than 400?

# %% [markdown]
# **16)** How many of the values in `new_radii` are even? Use Exercise 5 (putting it all together) from the `numpy` lesson as a reference.

# %%
#IGNORE THIS CELL - just displaying Figure 2
bumpiness = Image(filename='/astro/users/mlazz/PreMAP2019/homework/data/bumpiness_fig2.png') 
display(bumpiness)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **17)** Define a variable `r_star` with a value of 0.1. This variable will represent the 0.1 solar radius M-dwarf star used as a reference in this paper.
#
# Create an array called `transit_scatter` that contains 100 values between 0.2 and 1.4 that represents the transit scatter ($\sigma_B$) of 100 fictional planets.
#
# Use the equation printed on the figure to determine the bumpiness (B) of each of these planets. Save the bumpiness of each planet into an array called `bumpiness`. Print `bumpiness` to the screen.

# %% [markdown]
# **18)** What is the mean bumpiness of your planets? What is the standard deviation of the bumpiness? What is the median? *Hint: there are functions in numpy for all of these google it if you don't remember!*

# %%
mean =

# %%
median =

# %%
std_dev =

# %% [markdown]
# **19)** Let's say, more realistically, we changed the radius of the star in our bumpiness diagram to the radius of the Sun, R = 1 $R_{*}$. Using the value of the transit depth scatter from Figure 2 for both the wet and dry Earth, what would be the bumpiness in meters of the wet and the dry Earth?
